# %% [markdown]
# <a href="https://colab.research.google.com/github/lvarshitha7/ML-Lab/blob/main/Copy_of_Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# --**ML Lab using kaggle by the own dataset of placements.csv**

# %%
import pandas as pd
df=pd.read_excel('/content/cgpa.xlsx')
df['Result']=df['CGPA'].apply(lambda x: "Placed" if x>8 else "Not Placed")
print(df[['Rollno','Result']])
# Out:
#   Rollno      Result
# 0     x0      Placed
# 1     x1      Placed
# 2     x2      Placed
# 3     x3  Not Placed
# 4     x4      Placed
# 5     x5      Placed
# 6     x6  Not Placed
# 7     x7  Not Placed
# 8     x8  Not Placed
# 9     x9      Placed

# %% [markdown]
# #--**Titanic dataset**

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
df=pd.read_csv('/train_and_test2.csv')
x=df[['Age']]
y=df['2urvived']
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)
model=LinearRegression()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
mse=mean_squared_error(y_test,y_pred)
print("Mean Squared Error:",mse)
# Out:
# Mean Squared Error: 0.17367042744605332
